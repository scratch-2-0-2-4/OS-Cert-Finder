# %% [markdown]
# # OS-Cert-Center sur Google Colab
#
# Clonez le dépôt et exécutez les programmes directement !

# %%
# !git clone https://github.com/Scratch-OS-X/OS-Cert-Center.git
# %cd OS-Cert-Center

# %% [markdown]
# ## ⚠️ Mettre à jour (si vous avez déjà clôné avant)
#
# Exécutez cette cellule seulement si vous avez besoin de mettre à jour le code :

# %%
# Décommentez les 2 lignes ci-dessous pour mettre à jour
# %cd OS-Cert-Center
# !git pull origin main

# %% [markdown]
# ## 1. Générateur de Codes

# %%
# !python3 Generateur-de-codes.py

# %% [markdown]
# ## 2. Chercheur de Certificats

# %%
# !python3 Cert-Finder.py

# %% [markdown]
# ## 3. Admin (Modifier les Certificats)

# %%
# !python3 ADMIN.py
